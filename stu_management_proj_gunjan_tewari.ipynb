# %%
class Student:
    def __init__(self,name,rollno,m1,m2):
        self.name=name
        self.rollno=rollno
        self.m1=m1
        self.m2=m2
 
    # accept function which accepts the data of student
    def accept(self,name,rollno,marks1,marks2):
        ob=Student(name,rollno,marks1,marks2)
        l.append(ob)
 
    # display function which prints student data
    def display(self,ob):
        print("Name: ", ob.name)
        print("RollNo: ", ob.rollno)
        print("Marks1: ", ob.m1)
        print("Marks2: ", ob.m2)
        print("\n")
 
    # search function to search for student data on basis of roll no
    def search(self,rno):
        print("Searched Information")
        for i in range(len(l)):
            if(l[i].rollno==rno):
                return i
 
    # delete function to delete student data on basis of roll no
    def delete(self,rno):
        i=obj.search(rno)
        del l[i]
 
    # update function to update the student data on basis of roll no
    def update(self,rno,new):
        i=obj.search(rno)
        newrno=new
        l[i].rollno=newrno
        
#list to store student data
l=[]
# creating an object
obj=Student('', 0, 0, 0)
 
obj.accept('gunjan',1,84,78)
obj.accept('nikita',2,90,87)
obj.accept('sachin',3,76,68)
obj.accept('manas',4,57,69)
obj.accept('nayna',5,87,79)

print("\n")
print("Student information")
for i in range(len(l)):
    obj.display(l[i])
 
s=obj.search(3)
obj.display(l[s])
 
obj.delete(4)
print(len(l))
print("after deletion")
for i in range(len(l)):
    obj.display(l[i])
 
obj.update(5,4)
print(len(l))
print("List after updation")
for i in range(len(l)):
    obj.display(l[i])
# Out:
# Student information
# Name:  gunjan
# RollNo:  1
# Marks1:  84
# Marks2:  78
#
#
# Name:  nikita
# RollNo:  2
# Marks1:  90
# Marks2:  87
#
#
# Name:  sachin
# RollNo:  3
# Marks1:  76
# Marks2:  68
#
#
# Name:  manas
# RollNo:  4
# Marks1:  57
# Marks2:  69
#
#
# Name:  nayna
# RollNo:  5
# Marks1:  87
# Marks2:  79
#
#
# Searched Information
# Name:  sachin
# RollNo:  3
# Marks1:  76
# Marks2:  68
#
#
# Searched Information
# 4
# after deletion
# Name:  gunjan
# RollNo:  1
# Marks1:  84
# Marks2:  78
#
#
# Name:  nikita
# RollNo:  2
# Marks1:  90
# Marks2:  87
#
#
# Name:  sachin
# RollNo:  3
# Marks1:  76
# Marks2:  68
#
#
# Name:  nayna
# RollNo:  5
# Marks1:  87
# Marks2:  79
#
#
# Searched Information
# 4
# List after updation
# Name:  gunjan
# RollNo:  1
# Marks1:  84
# Marks2:  78
#
#
# Name:  nikita
# RollNo:  2
# Marks1:  90
# Marks2:  87
#
#
# Name:  sachin
# RollNo:  3
# Marks1:  76
# Marks2:  68
#
#
# Name:  nayna
# RollNo:  4
# Marks1:  87
# Marks2:  79
